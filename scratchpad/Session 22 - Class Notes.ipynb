# %%
print("here")
# Out:
# here

# %%
class Shape:
    pass

class Ellipse(Shape):
    pass

class Circle(Ellipse):
    pass

class Polygon(Shape):
    pass

class Rectangle(Polygon):
    pass

class Square(Rectangle):
    pass

class Triangle(Polygon):
    pass

# %%
issubclass(Ellipse, Shape)
# Out:
# True

# %%
s = Shape()
e = Ellipse()
try:
    issubclass(e, s)
except TypeError as ex:
    print(ex)
# Out:
# issubclass() arg 1 must be a class

# %%
isinstance(e, Ellipse)
# Out:
# True

# %%
isinstance(e, Shape)
# Out:
# True

# %%
issubclass(Square, Shape)
# Out:
# True

# %%
sq = Square()

# %%
isinstance(sq, Square)
# Out:
# True

# %%
isinstance(sq, Rectangle)
# Out:
# True

# %%
isinstance(sq, Polygon)
# Out:
# True

# %%
isinstance(sq, Polygon)
# Out:
# True

# %%
issubclass(Square, Ellipse)
# Out:
# False

# %%
isinstance(sq, Ellipse)
# Out:
# False

# %%
class Person:
    pass

# %%
issubclass(Person, object)
# Out:
# True

# %%
p = Person()

# %%
isinstance(p, Person)
# Out:
# True

# %%
issubclass(Square, object)
# Out:
# True

# %%
isinstance(sq, object)
# Out:
# True

# %% [markdown]
# # Object

# %%
type(object)
# Out:
# type

# %%
type(int), type(str), type(dict)
# Out:
# (type, type, type)

# %%
class Person:
    pass

# %%
issubclass(Person, object)
# Out:
# True

# %%
issubclass(int, object)
# Out:
# True

# %%
import math

# %%
type(math)
# Out:
# module

# %%
ty = type(math)

# %%
type(ty)
# Out:
# type

# %%
issubclass(ty, object)
# Out:
# True

# %%
import types

# %%
dir(types)
# Out:
# ['AsyncGeneratorType',
#  'BuiltinFunctionType',
#  'BuiltinMethodType',
#  'CellType',
#  'ClassMethodDescriptorType',
#  'CodeType',
#  'CoroutineType',
#  'DynamicClassAttribute',
#  'FrameType',
#  'FunctionType',
#  'GeneratorType',
#  'GenericAlias',
#  'GetSetDescriptorType',
#  'LambdaType',
#  'MappingProxyType',
#  'MemberDescriptorType',
#  'MethodDescriptorType',
#  'MethodType',
#  'MethodWrapperType',
#  'ModuleType',
#  'SimpleNamespace',
#  'TracebackType',
#  'WrapperDescriptorType',
#  '_GeneratorWrapper',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_calculate_meta',
#  '_cell_factory',
#  'coroutine',
#  'new_class',
#  'prepare_class',
#  'resolve_bases']

# %%
def my_func():
    pass

# %%
type(my_func)
# Out:
# function

# %%
types.FunctionType is type(my_func)
# Out:
# True

# %%
issubclass(types.FunctionType, object)
# Out:
# True

# %%
isinstance(my_func,  object)
# Out:
# True

# %%
dir(object)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
o1 = object()

# %%
str(o1)
# Out:
# '<object object at 0x000002703A188B30>'

# %%
repr(o1)
# Out:
# '<object object at 0x000002703A188B30>'

# %%
class Person:
    pass

# %%
p = Person()
str(p)
# Out:
# '<__main__.Person object at 0x0000027039F99DF0>'

# %%
o1 = object()
o2 = object()

# %%
id(o1), id(o2)
# Out:
# (2681034280432, 2681034280672)

# %%
o1 is o2, o1 == o2, o1 is o1, o1 == o1
# Out:
# (False, False, True, True)

# %%
p1 = Person()
p2 = Person()

p1 is p2, p1 == p2, p1 is p1, p1 == p1
# Out:
# (False, False, True, True)

# %%
id(Person.__eq__)
# Out:
# 2680970285840

# %%
id(object.__eq__)
# Out:
# 2680970285840

# %%
id(Person.__init__), id(object.__init__)
# Out:
# (2680970286160, 2680970286160)

# %%
class Person:
    def __init__(self):
        pass

# %%
id(Person.__init__), id(object.__init__)
# Out:
# (2681049867312, 2680970286160)

# %%
class Person:
    pass
id(Person.__init__), id(object.__init__)
# Out:
# (2680970286160, 2680970286160)

# %% [markdown]
# # Overriding

# %%
def print(a):
    return a*a

# %%
print("red")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38152\1531207319.py in <module>
# ----> 1 print("red")
#
# ~\AppData\Local\Temp\ipykernel_38152\3350320130.py in print(a)
#       1 def print(a):
# ----> 2     return a*a
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
del print

# %%
print("red")
# Out:
# red

# %%
class Person:
    pass

# %%
p = Person()
str(p)
# Out:
# '<__main__.Person object at 0x0000027039EA2370>'

# %%
class Person:
    def __str__(self):
        return 'Person class'

# %%
p = Person()

# %%
str(p)
# Out:
# 'Person class'

# %%
class Person:
    def __repr__(self):
        return 'Person()'

# %%
p = Person()

# %%
str(p)
# Out:
# 'Person()'

# %%
class Shape:
    def __init__(self, name):
        self.name = name
        
    def info(self):
         return f'Shape.info called for Shape({self.name})'
    
    def extended_info(self):
        return f'Shape.extended_info called for Shape({self.name})'
    
class Polygon(Shape):
    def __init__(self, name):
        self.name = name  # we'll come back to this later in the context of using the super()
        
    def info(self):
        return f'Polygon info called for Polygon({self.name})'

# %%
p = Polygon('square')

# %%
p.info()
# Out:
# 'Polygon info called for Polygon(square)'

# %%
p.extended_info()
# Out:
# 'Shape.extended_info called for Shape(square)'

# %%
class Shape:
    def __init__(self, name):
        self.name = name
        
    def info(self):
         return f'Shape.info called for Shape({self.name})'
    
    def extended_info(self):
        return f'Shape.extended_info called for Shape({self.name})', self.info()
    
class Polygon(Shape):
    def __init__(self, name):
        self.name = name  # we'll come back to this later in the context of using the super()
        
    def info(self):
        return f'Polygon.info called for Polygon({self.name})'

# %%
p = Polygon('Square')

# %%
p.info() # :(
# Out:
# 'Polygon.info called for Polygon(Square)'

# %%
print(p.extended_info())
# Out:
# ('Shape.extended_info called for Shape(Square)', 'Polygon.info called for Polygon(Square)')

# %%
class Person:
    def __str__(self):
        return 'Person.__str__ called'
    
class Student(Person):
    def __repr__(self):
        return 'Student.__repr__ called'

# %%
s = Student()

# %%
str(s)
# Out:
# 'Person.__str__ called'

# %%
repr(s)
# Out:
# 'Student.__repr__ called'

# %%
class Person:
    def __str__(self):
        print('Person.__str__ called')
        return self.__repr__()
    
class Student(Person):
    def __repr__(self):
        return 'Student.__repr__ called'

# %%
s = Student()

# %%
str(s)
# Out:
# Person.__str__ called
# 'Student.__repr__ called'

# %%
class Person:
    def __str__(self):
        print('Person.__str__ called')
        return self.__repr__()
    
class Student(Person):
    def __repr__(self):
        return 'Student.__repr__ called'

# %%
s = Student()

# %%
str(s)
# Out:
# Person.__str__ called
# 'Student.__repr__ called'

# %%
repr(s)
# Out:
# 'Student.__repr__ called'

# %% [markdown]
# # Extending

# %%
class Person:
    pass

# %%
class Student(Person):
    def study(self):
        return 'study... study... study...'

# %%
p = Person()

# %%
try:
    p.study()
except AttributeError as ex:
    print(ex)
# Out:
# 'Person' object has no attribute 'study'

# %%
s = Student()

# %%
isinstance(s, Person)
# Out:
# True

# %%
s.study()
# Out:
# 'study... study... study...'

# %%
class Person:
    def routine(self):
        return self.eat() + self.study() + self.sleep()
        
    def eat(self):
        return 'Person eats...'
    
    def sleep(self):
        return 'Person sleeps...'

# %%
p = Person()

try:
    p.routine()
except AttributeError as ex:
    print(ex)
# Out:
# 'Person' object has no attribute 'study'

# %%
class Student(Person):
    def study(self):
        return 'Student studies...'

# %%
s = Student()

# %%
s.routine()
# Out:
# 'Person eats...Student studies...Person sleeps...'

# %%
class Person:
    def routine(self):
        result = self.eat()
        if hasattr(self, 'study'):
            result += self.study()
        result += self.sleep()
        return result
    
    def eat(self):
        return 'Person eats...'
    
    def sleep(self):
        return 'Person sleeps...'

# %%
p = Person()

# %%
p.routine()
# Out:
# 'Person eats...Person sleeps...'

# %%
class Student(Person):
    def study(self):
        return 'Student studies...'

# %%
s = Student()

# %%
s.routine()
# Out:
# 'Person eats...Student studies...Person sleeps...'

# %%
class Person:
    def __init__(self, name):
        self.name = name
        
    def routine(self):
        return NotImplemented

# %%
p = Person('Alex')

# %%
p.routine()
# Out:
# NotImplemented

# %%
class Student(Person):
    def routine(self):
        return 'Eat...Study...Sleep'

# %%
class Teacher(Person):
    def routine(self):
        return 'Eat...Teach...Sleep'

# %%
s = Student('Alex')

# %%
t = Teacher('Fred')

# %%
s.routine()
# Out:
# 'Eat...Study...Sleep'

# %%
t.routine()
# Out:
# 'Eat...Teach...Sleep'

# %%
class Account:
    apr = 3.0
    
    def __init__(self, account_number, balance):
        self.account_number = account_number
        self.balance = balance
        self.account_type = 'Generic Account'
        
    def calc_interest(self):
        return f'Calc interest on {self.account_type} with APR = {self.apr}'

# %%
a = Account(123, 100)

# %%
a.apr, a.account_type, a.calc_interest()
# Out:
# (3.0, 'Generic Account', 'Calc interest on Generic Account with APR = 3.0')

# %%
class Savings(Account):
    apr = 5.0
    
    def __init__(self, account_number, balance):
        self.account_number = account_number  # We'll revisit this later - this is clumsy
        self.balance = balance
        self.account_type = 'Savings Account'

# %%
s = Savings(234, 200)

# %%
s.apr, s.account_type, s.calc_interest()
# Out:
# (5.0, 'Savings Account', 'Calc interest on Savings Account with APR = 5.0')

# %%
class Account:
    apr = 3.0
    
    def __init__(self, account_number, balance):
        self.account_number = account_number
        self.balance = balance
        self.account_type = 'Generic Account'
        
    def calc_interest(self):
        return f'Calc interest on {self.account_type} with APR = {Account.apr}'
        
        
class Savings(Account):
    apr = 5.0
    
    def __init__(self, account_number, balance):
        self.account_number = account_number  # We'll revisit this later - this is clumsy
        self.balance = balance
        self.account_type = 'Savings Account'

# %%
s = Savings(123, 100)
s.calc_interest()
# Out:
# 'Calc interest on Savings Account with APR = 3.0'

# %%
class Account:
    apr = 3.0
    def __init__(self, account_number, balance):
        self.account_number = account_number
        self.balance = balance
        self.account_type = 'Generic Account'
    def calc_interest(self):
        return f'Calc interest on {self.account_type} with APR = {self.__class__.apr}'
class Savings(Account):
    apr = 5.0
    def __init__(self, account_number, balance):
        self.account_number = account_number  # We'll revisit this later - this is clumsy
        self.balance = balance
        self.account_type = 'Savings Account' 
a = Account(123, 100)
s = Savings(234, 200)
a.calc_interest(), s.calc_interest()
# Out:
# ('Calc interest on Generic Account with APR = 3.0',
#  'Calc interest on Savings Account with APR = 5.0')

# %% [markdown]
# # Delegating to Patent

# %%
# super()
class Person:
    def work(self):
        return 'Person works...'
    
class Student(Person):
    def work(self):
        result = super().work()
        return f'Student works... and {result}'

# %%
s = Student()

# %%
s.work()
# Out:
# 'Student works... and Person works...'

# %%
class Person:
    def work(self):
        return 'Person works...'
    
class Student(Person):
    pass

class PythonStudent(Student):
    def work(self):
        result = super().work()
        return f'PythonStudent codes... and {result}'

# %%
ps = PythonStudent()

# %%
ps.work()
# Out:
# 'PythonStudent codes... and Person works...'

# %%
class Person:
    def work(self):
        return 'Person works...'
    
class Student(Person):
    def work(self):
        result = super().work()
        return f'Student studies... and {result}'
    
class PythonStudent(Student):
    def work(self):
        result = super().work()
        return f'PythonStudent codes... and {result}'

# %%
ps = PythonStudent()
ps.work()
# Out:
# 'PythonStudent codes... and Student studies... and Person works...'

# %%
class Person:
    def work(self):
        return 'Person works...'
    
class Student(Person):
    def study(self):
        return 'Student studies...'
    
class PythonStudent(Student):
    def code(self):
        result_1 = self.work()
        result_2 = self.study()
        return f'{result_1} and {result_2} and PythonStudent codes...'

# %%
ps = PythonStudent()

# %%
ps.code()
# Out:
# 'Person works... and Student studies... and PythonStudent codes...'

# %%
class Person:
    def set_name(self, value):
        print('Setting name using Person set_name method...')
        self.name = value
        
class Student(Person):
    def set_name(self, value):
        print('Student class delegating back to parent...')
        super().set_name(value)

# %%
s = Student()

# %%
s.__dict__
# Out:
# {}

# %%
s.set_name('Eric')
# Out:
# Student class delegating back to parent...
# Setting name using Person set_name method...

# %%
s.__dict__
# Out:
# {'name': 'Eric'}

# %%
class Person:
    def __init__(self, name):
        self.name = name
        
class Student(Person):
    def __init__(self, name, student_number):
        super().__init__(name)
        self.student_number = student_number

# %%
s = Student('Python', 30)

# %%
s.__dict__
# Out:
# {'name': 'Python', 'student_number': 30}

# %%
s.name
# Out:
# 'Python'

# %%
class Person:
    def __init__(self):
        print('Person __init__')
        
class Student(Person):
    pass

# %%
s = Student()
# Out:
# Person __init__

# %%
class Person:
    def __init__(self, name):
        print('Person __init__ called...')
        self.name = name
        
class Student(Person):
    pass

# %%
try:
    s = Student()
except TypeError as ex:
    print(ex)
# Out:
# __init__() missing 1 required positional argument: 'name'

# %%
class Person:
    def __init__(self, name):
        print('Person __init__ called...')
        self.name = name
        
class Student(Person):
    pass

# %%
s = Student('Alex')
# Out:
# Person __init__ called...

# %%
s.__dict__
# Out:
# {'name': 'Alex'}

# %%
class Person:
    def __init__(self):
        print('Person __init__ called...')
        
class Student(Person):
    def __init__(self):
        print('Student __init__ called...')

# %%
s = Student()
# Out:
# Student __init__ called...

# %%
class Person:
    def __init__(self):
        print('Person __init__ called...')

class Student(Person):
    def __init__(self):
        super().__init__()
        print('Student __init__ called...')

# %%
s = Student()
# Out:
# Person __init__ called...
# Student __init__ called...

# %%
from math import pi
from numbers import Real

class Circle:
    def __init__(self, r):
        self._r = r
        self._area = None
        self._perimeter = None
        
    @property
    def radius(self):
        return self._r
    
    @radius.setter
    def radius(self, r):
        if isinstance(r, Real) and r > 0:
            self._r = r
            self._area = None
            self._perimeter = None
        else:
            raise ValueError('Radius must a positive real number.')
            
    @property
    def area(self):
        if self._area is None:
            self._area = pi * self.radius ** 2
        return self._area
            
    @property
    def perimeter(self):
        if self._perimeter is None:
            self._perimeter = 2 * pi * self.radius
        return self._perimeter

# %%
class UnitCircle(Circle):
    def __init__(self):
        super().__init__(1)

# %%
u = UnitCircle()

# %%
u.radius, u.area, u.perimeter
# Out:
# (1, 3.141592653589793, 6.283185307179586)

# %% [markdown]
# # Slots

# %%
class Location:
    __slots__ = 'name', '_longitude', '_latitude'
    
    def __init__(self, name, longitude, latitude):
        self._longitude = longitude
        self._latitude = latitude
        self.name = name
        
    @property
    def longitude(self):
        return self._longitude
    
    @property
    def latitude(self):
        return self._latitude

# %%
Location.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__slots__': ('name', '_longitude', '_latitude'),
#               '__init__': <function __main__.Location.__init__(self, name, longitude, latitude)>,
#               'longitude': <property at 0x2703b18c9a0>,
#               'latitude': <property at 0x2703b18d310>,
#               '_latitude': <member '_latitude' of 'Location' objects>,
#               '_longitude': <member '_longitude' of 'Location' objects>,
#               'name': <member 'name' of 'Location' objects>,
#               '__doc__': None})

# %%
Location.map_service = 'Google Maps'

# %%
Location.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__slots__': ('name', '_longitude', '_latitude'),
#               '__init__': <function __main__.Location.__init__(self, name, longitude, latitude)>,
#               'longitude': <property at 0x2703b18c9a0>,
#               'latitude': <property at 0x2703b18d310>,
#               '_latitude': <member '_latitude' of 'Location' objects>,
#               '_longitude': <member '_longitude' of 'Location' objects>,
#               'name': <member 'name' of 'Location' objects>,
#               '__doc__': None,
#               'map_service': 'Google Maps'})

# %%
l = Location('Mumbai', 19.0760, 72.8777)

# %%
l.name, l.longitude, l.latitude
# Out:
# ('Mumbai', 19.076, 72.8777)

# %%
try:
    l.__dict__
except AttributeError as ex:
    print(ex)
# Out:
# 'Location' object has no attribute '__dict__'

# %%
class Location:
    __slots__ = 'name', '_longitude', '_latitude'
    def __init__(self, name, longitude, latitude, password):
        self._longitude = longitude
        self._latitude = latitude
        self.name = name
        self.password = password
        
    @property
    def longitude(self):
        return self._longitude
    
    @property
    def latitude(self):
        return self._latitude

# %%
l = Location('Mumbai', 19.0760, 72.8777, "ferrari")
l.name, l.longitude, l.latitude
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38152\105171604.py in <module>
# ----> 1 l = Location('Mumbai', 19.0760, 72.8777, "ferrari")
#       2 l.name, l.longitude, l.latitude
#
# ~\AppData\Local\Temp\ipykernel_38152\493072232.py in __init__(self, name, longitude, latitude, password)
#       5         self._latitude = latitude
#       6         self.name = name
# ----> 7         self.password = password
#       8
#       9     @property
#
# AttributeError: 'Location' object has no attribute 'password'

# %%
l.__dict__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38152\2287854891.py in <module>
# ----> 1 l.__dict__
#
# AttributeError: 'Location' object has no attribute '__dict__'

# %%
class Person:
    __slots__ = ['name', 'age']

    def __init__(self, name, age):
        self.name = name
        self.age = age
p = Person("Rajesh", 30)
p.name
# Out:
# 'Rajesh'

# %%
p.name = "Ramesh"
p.name
# Out:
# 'Ramesh'

# %%
p.address = "Bangalore"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38152\3721823824.py in <module>
# ----> 1 p.address = "Bangalore"
#
# AttributeError: 'Person' object has no attribute 'address'

# %%
class Person:
    __slots__ = ["name", "_age"]

    def __init__(self, name, age):
        self.name = name
        self._age = age
    
    @property
    def age (self):
        return self._age

# %%
person = Person("Ram", 30)

# %%
print(person.name)
# Out:
# Ram

# %%
print(person.age)
# Out:
# 30

# %%
person._age
# Out:
# 30

# %%
person.age = 25
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38152\1623193561.py in <module>
# ----> 1 person.age = 25
#
# AttributeError: can't set attribute

# %%
person._age = 45

# %%
class Human:
    def __init__(self):
        self.age = 45


h = Human()
h.age
# Out:
# 45

# %%
class Person(Human):
    __slots__ = ['name', 'age']
    def __init__(self, name):
        super().__init__()
        self.name = name

# %%
person = Person("Alice")

# %%
person.age
# Out:
# 45

# %%
class Person:
    __slots__ = 'name',
    
    def __init__(self, name):
        self.name = name

class Student(Person):
    pass

# %%
p = Person('Eric')
try:
    print(p.__dict__)
except AttributeError as ex:
    print(ex)
# Out:
# 'Person' object has no attribute '__dict__'

# %%
s = Student('Alex')

# %%
s.name, s.__dict__
# Out:
# ('Alex', {})

# %%
s.age = 19

# %%
s.__dict__
# Out:
# {'age': 19}

# %%
s.name, s.age
# Out:
# ('Alex', 19)

# %%
class Student(Person):
    __slots__ = tuple()

# %%
s = Student('Alex')

# %%
try:
    print(s.__dict__)
except AttributeError as ex:
    print(ex)
# Out:
# 'Student' object has no attribute '__dict__'

# %%
class Person:
    __slots__ = 'name',
    
    def __init__(self, name):
        self.name = name
        
class Student(Person):
    __slots__ = 'school', 'student_number'
    
    def __init__(self, name, school, student_number):
        super().__init__(name)
        self.school = school
        self.student_number = student_number

# %%
s = Student('James', 'MI6 Prep', '007')

# %%
s.name, s.school, s.student_number
# Out:
# ('James', 'MI6 Prep', '007')

# %%
class Person:
    def __init__(self, name):
        self.name = name
        
class Student(Person):
    __slots__ = 'age',
    
    def __init__(self, name, age):
        super().__init__(name)
        self.age = age

# %%
s = Student('Python', 30)

# %%
s.name, s.age, s.__dict__
# Out:
# ('Python', 30, {'name': 'Python'})

# %%
class Person:
    __slots__ = '_name', 'age'
    
    def __init__(self, name, age):
        self.name = name
        self.age = age
        
    @property
    def name(self):
        return self._name
    
    @name.setter
    def name(self, name):
        self._name = name

# %%
p = Person('Eric', 78)

# %%
p.name, p.age
# Out:
# ('Eric', 78)
